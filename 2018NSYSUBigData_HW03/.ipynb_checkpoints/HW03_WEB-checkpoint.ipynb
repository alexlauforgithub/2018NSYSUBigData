# %%
from sklearn import preprocessing
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import cross_val_score

import warnings
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
train = pd.read_csv("train.csv")
test = pd.read_csv("test.csv")
submit = pd.read_csv('gender_submission.csv')

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.6+ KB

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
# PassengerId    418 non-null int64
# Pclass         418 non-null int64
# Name           418 non-null object
# Sex            418 non-null object
# Age            332 non-null float64
# SibSp          418 non-null int64
# Parch          418 non-null int64
# Ticket         418 non-null object
# Fare           417 non-null float64
# Cabin          91 non-null object
# Embarked       418 non-null object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 36.0+ KB

# %%
train.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
test.describe()
# Out:
#        PassengerId      Pclass         Age       SibSp       Parch        Fare
# count   418.000000  418.000000  332.000000  418.000000  418.000000  417.000000
# mean   1100.500000    2.265550   30.272590    0.447368    0.392344   35.627188
# std     120.810458    0.841838   14.181209    0.896760    0.981429   55.907576
# min     892.000000    1.000000    0.170000    0.000000    0.000000    0.000000
# 25%     996.250000    1.000000   21.000000    0.000000    0.000000    7.895800
# 50%    1100.500000    3.000000   27.000000    0.000000    0.000000   14.454200
# 75%    1204.750000    3.000000   39.000000    1.000000    0.000000   31.500000
# max    1309.000000    3.000000   76.000000    8.000000    9.000000  512.329200

# %% [markdown]
# ### 合併train、test資料

# %%
#合併train、test
data=train.append(test)

# %%
data
# Out:
#       Age        Cabin Embarked      Fare  \
# 0    22.0          NaN        S    7.2500
# 1    38.0          C85        C   71.2833
# 2    26.0          NaN        S    7.9250
# 3    35.0         C123        S   53.1000
# 4    35.0          NaN        S    8.0500
# 5     NaN          NaN        Q    8.4583
# 6    54.0          E46        S   51.8625
# 7     2.0          NaN        S   21.0750
# 8    27.0          NaN        S   11.1333
# 9    14.0          NaN        C   30.0708
# 10    4.0           G6        S   16.7000
# 11   58.0         C103        S   26.5500
# 12   20.0          NaN        S    8.0500
# 13   39.0          NaN        S   31.2750
# 14   14.0          NaN        S    7.8542
# 15   55.0          NaN        S   16.0000
# 16    2.0          NaN        Q   29.1250
# 17    NaN          NaN        S   13.0000
# 18   31.0          NaN        S   18.0000
# 19    NaN          NaN        C    7.2250
# 20   35.0          NaN        S   26.0000
# 21   34.0          D56        S   13.0000
# 22   15.0          NaN        Q    8.0292
# 23   28.0           A6        S   35.5000
# 24    8.0          NaN        S   21.0750
# 25   38.0          NaN        S   31.3875
# 26    NaN          NaN        C    7.2250
# 27   19.0  C23 C25 C27        S  263.0000
# 28    NaN          NaN        Q    7.8792
# 29    NaN          NaN        S    7.8958
# ..    ...          ...      ...       ...
# 388  21.0          NaN        Q    7.7500
# 389   6.0          NaN        S   21.0750
# 390  23.0          B24        S   93.5000
# 391  51.0          D28        S   39.4000
# 392  13.0          NaN        S   20.2500
# 393  47.0          NaN        S   10.5000
# 394  29.0          NaN        S   22.0250
# 395  18.0          C31        S   60.0000
# 396  24.0          NaN        Q    7.2500
# 397  48.0          B41        C   79.2000
# 398  22.0          NaN        S    7.7750
# 399  31.0          NaN        Q    7.7333
# 400  30.0           C7        S  164.8667
# 401  38.0          NaN        S   21.0000
# 402  22.0          NaN        C   59.4000
# 403  17.0          NaN        S   47.1000
# 404  43.0          D40        C   27.7208
# 405  20.0          D38        C   13.8625
# 406  23.0          NaN        S   10.5000
# 407  50.0          C80        C  211.5000
# 408   NaN          NaN        Q    7.7208
# 409   3.0          NaN        S   13.7750
# 410   NaN          NaN        Q    7.7500
# 411  37.0          C78        Q   90.0000
# 412  28.0          NaN        S    7.7750
# 413   NaN          NaN        S    8.0500
# 414  39.0         C105        C  108.9000
# 415  38.5          NaN        S    7.2500
# 416   NaN          NaN        S    8.0500
# 417   NaN          NaN        C   22.3583
#
#                                                   Name  Parch  PassengerId  \
# 0                              Braund, Mr. Owen Harris      0            1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...      0            2
# 2                               Heikkinen, Miss. Laina      0            3
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)      0            4
# 4                             Allen, Mr. William Henry      0            5
# 5                                     Moran, Mr. James      0            6
# 6                              McCarthy, Mr. Timothy J      0            7
# 7                       Palsson, Master. Gosta Leonard      1            8
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)      2            9
# 9                  Nasser, Mrs. Nicholas (Adele Achem)      0           10
# 10                     Sandstrom, Miss. Marguerite Rut      1           11
# 11                            Bonnell, Miss. Elizabeth      0           12
# 12                      Saundercock, Mr. William Henry      0           13
# 13                         Andersson, Mr. Anders Johan      5           14
# 14                Vestrom, Miss. Hulda Amanda Adolfina      0           15
# 15                    Hewlett, Mrs. (Mary D Kingcome)       0           16
# 16                                Rice, Master. Eugene      1           17
# 17                        Williams, Mr. Charles Eugene      0           18
# 18   Vander Planke, Mrs. Julius (Emelia Maria Vande...      0           19
# 19                             Masselmani, Mrs. Fatima      0           20
# 20                                Fynney, Mr. Joseph J      0           21
# 21                               Beesley, Mr. Lawrence      0           22
# 22                         McGowan, Miss. Anna "Annie"      0           23
# 23                        Sloper, Mr. William Thompson      0           24
# 24                       Palsson, Miss. Torborg Danira      1           25
# 25   Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...      5           26
# 26                             Emir, Mr. Farred Chehab      0           27
# 27                      Fortune, Mr. Charles Alexander      2           28
# 28                       O'Dwyer, Miss. Ellen "Nellie"      0           29
# 29                                 Todoroff, Mr. Lalio      0           30
# ..                                                 ...    ...          ...
# 388                               Canavan, Mr. Patrick      0         1280
# 389                        Palsson, Master. Paul Folke      1         1281
# 390                         Payne, Mr. Vivian Ponsonby      0         1282
# 391     Lines, Mrs. Ernest H (Elizabeth Lindsey James)      1         1283
# 392                      Abbott, Master. Eugene Joseph      2         1284
# 393                               Gilbert, Mr. William      0         1285
# 394                           Kink-Heilmann, Mr. Anton      1         1286
# 395     Smith, Mrs. Lucien Philip (Mary Eloise Hughes)      0         1287
# 396                               Colbert, Mr. Patrick      0         1288
# 397  Frolicher-Stehli, Mrs. Maxmillian (Margaretha ...      1         1289
# 398                     Larsson-Rondberg, Mr. Edvard A      0         1290
# 399                           Conlon, Mr. Thomas Henry      0         1291
# 400                            Bonnell, Miss. Caroline      0         1292
# 401                                    Gale, Mr. Harry      0         1293
# 402                     Gibson, Miss. Dorothy Winifred      1         1294
# 403                             Carrau, Mr. Jose Pedro      0         1295
# 404                       Frauenthal, Mr. Isaac Gerald      0         1296
# 405       Nourney, Mr. Alfred (Baron von Drachstedt")"      0         1297
# 406                          Ware, Mr. William Jeffery      0         1298
# 407                         Widener, Mr. George Dunton      1         1299
# 408                    Riordan, Miss. Johanna Hannah""      0         1300
# 409                          Peacock, Miss. Treasteall      1         1301
# 410                             Naughton, Miss. Hannah      0         1302
# 411    Minahan, Mrs. William Edward (Lillian E Thorpe)      0         1303
# 412                     Henriksson, Miss. Jenny Lovisa      0         1304
# 413                                 Spector, Mr. Woolf      0         1305
# 414                       Oliva y Ocana, Dona. Fermina      0         1306
# 415                       Saether, Mr. Simon Sivertsen      0         1307
# 416                                Ware, Mr. Frederick      0         1308
# 417                           Peter, Master. Michael J      1         1309
#
#      Pclass     Sex  SibSp  Survived              Ticket
# 0         3    male      1       0.0           A/5 21171
# 1         1  female      1       1.0            PC 17599
# 2         3  female      0       1.0    STON/O2. 3101282
# 3         1  female      1       1.0              113803
# 4         3    male      0       0.0              373450
# 5         3    male      0       0.0              330877
# 6         1    male      0       0.0               17463
# 7         3    male      3       0.0              349909
# 8         3  female      0       1.0              347742
# 9         2  female      1       1.0              237736
# 10        3  female      1       1.0             PP 9549
# 11        1  female      0       1.0              113783
# 12        3    male      0       0.0           A/5. 2151
# 13        3    male      1       0.0              347082
# 14        3  female      0       0.0              350406
# 15        2  female      0       1.0              248706
# 16        3    male      4       0.0              382652
# 17        2    male      0       1.0              244373
# 18        3  female      1       0.0              345763
# 19        3  female      0       1.0                2649
# 20        2    male      0       0.0              239865
# 21        2    male      0       1.0              248698
# 22        3  female      0       1.0              330923
# 23        1    male      0       1.0              113788
# 24        3  female      3       0.0              349909
# 25        3  female      1       1.0              347077
# 26        3    male      0       0.0                2631
# 27        1    male      3       0.0               19950
# 28        3  female      0       1.0              330959
# 29        3    male      0       0.0              349216
# ..      ...     ...    ...       ...                 ...
# 388       3    male      0       NaN              364858
# 389       3    male      3       NaN              349909
# 390       1    male      0       NaN               12749
# 391       1  female      0       NaN            PC 17592
# 392       3    male      0       NaN           C.A. 2673
# 393       2    male      0       NaN          C.A. 30769
# 394       3    male      3       NaN              315153
# 395       1  female      1       NaN               13695
# 396       3    male      0       NaN              371109
# 397       1  female      1       NaN               13567
# 398       3    male      0       NaN              347065
# 399       3    male      0       NaN               21332
# 400       1  female      0       NaN               36928
# 401       2    male      1       NaN               28664
# 402       1  female      0       NaN              112378
# 403       1    male      0       NaN              113059
# 404       1    male      1       NaN               17765
# 405       2    male      0       NaN       SC/PARIS 2166
# 406       2    male      1       NaN               28666
# 407       1    male      1       NaN              113503
# 408       3  female      0       NaN              334915
# 409       3  female      1       NaN  SOTON/O.Q. 3101315
# 410       3  female      0       NaN              365237
# 411       1  female      1       NaN               19928
# 412       3  female      0       NaN              347086
# 413       3    male      0       NaN           A.5. 3236
# 414       1  female      0       NaN            PC 17758
# 415       3    male      0       NaN  SOTON/O.Q. 3101262
# 416       3    male      0       NaN              359309
# 417       3    male      1       NaN                2668
#
# [1309 rows x 12 columns]

# %%
#append合併之後，造成index重複問題，因此要將index重新設定
data.reset_index(inplace=True,drop=True)

# %% [markdown]
# #                    【資料分析】

# %% [markdown]
# ## ------------------間斷資料分析----------------------

# %% [markdown]
# ###  sns.countplot(data[' '],hue=data[' '])

# %%
# 【生存率分析】
# 發現 死亡的比例:6成、生存的比例:4成
sns.countplot(data['Survived'])

# %%
# 【艙等】 跟生存率的關係
# 發現 生存率最高排序=>1艙等、2艙等、3艙等
sns.countplot(data['Pclass'],hue=data['Survived'])

# %%
# 【性別】跟生存率的關係，發現女生生存率是男生的好幾倍。
sns.countplot(data['Sex'],hue=data['Survived'])

# %%
# 【出發港口】跟生存率  s港出發的都比較容易死亡
sns.countplot(data['Embarked'],hue=data['Survived'])

# %% [markdown]
# ## ------------------連續資料分析-----------------------

# %% [markdown]
# ### sns.FacetGrid(data, col='間斷資料欄位')

# %% [markdown]
# ### 資料名.map(sns.distplot, '連續資料欄位', kde=False)

# %%
# 【年齡】跟生存率    年齡小的存活比例高
# sns.FacetGrid g.map sns.distplot  
g = sns.FacetGrid(data, col='Survived')
g.map(sns.distplot, 'Age', kde=False)

# %%
# 【票價】、生存率  票價低的乘客死亡率高
g = sns.FacetGrid(data, col='Survived')
g.map(sns.distplot, 'Fare', kde=False)

# %%
# 【父母＋小孩的數量】、生存率  
# 沒有跟父母小孩一起來的 生存率低
g = sns.FacetGrid(data, col='Survived')
g.map(sns.distplot, 'Parch', kde=False)

# %%
# 【兄弟姊妹＋丈夫妻子的數量】、生存率  
# 沒有帶兄弟姊妹＋丈夫妻子一起來的 生存率低
g = sns.FacetGrid(data, col='Survived')
g.map(sns.distplot, 'SibSp', kde=False)

# %%
# 把家人加在同一欄位
data['Family_Size']=data['Parch']+data['SibSp']

# %%
g = sns.FacetGrid(data, col='Survived')
g.map(sns.distplot, 'Family_Size', kde=False)

# %% [markdown]
# # 【特徵分析】

# %% [markdown]
# ## 1. ----------------缺失值處理--------------------------

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 13 columns):
# Age            1046 non-null float64
# Cabin          295 non-null object
# Embarked       1307 non-null object
# Fare           1308 non-null float64
# Name           1309 non-null object
# Parch          1309 non-null int64
# PassengerId    1309 non-null int64
# Pclass         1309 non-null int64
# Sex            1309 non-null object
# SibSp          1309 non-null int64
# Survived       891 non-null float64
# Ticket         1309 non-null object
# Family_Size    1309 non-null int64
# dtypes: float64(3), int64(5), object(5)
# memory usage: 133.0+ KB

# %%
data['Age'].fillna(data['Age'].mean(), inplace=True)
data['Embarked'].fillna('S', inplace=True)
data['Fare'].fillna(data['Fare'].mean(), inplace=True)
data['Survived'].fillna('0', inplace=True)

# %%
data.head()
# Out:
#     Age Cabin Embarked     Fare  \
# 0  22.0   NaN        S   7.2500
# 1  38.0   C85        C  71.2833
# 2  26.0   NaN        S   7.9250
# 3  35.0  C123        S  53.1000
# 4  35.0   NaN        S   8.0500
#
#                                                 Name  Parch  PassengerId  \
# 0                            Braund, Mr. Owen Harris      0            1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...      0            2
# 2                             Heikkinen, Miss. Laina      0            3
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)      0            4
# 4                           Allen, Mr. William Henry      0            5
#
#    Pclass     Sex  SibSp Survived            Ticket  Family_Size
# 0       3    male      1        0         A/5 21171            1
# 1       1  female      1        1          PC 17599            1
# 2       3  female      0        1  STON/O2. 3101282            0
# 3       1  female      1        1            113803            1
# 4       3    male      0        0            373450            0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 13 columns):
# Age            1309 non-null float64
# Cabin          295 non-null object
# Embarked       1309 non-null object
# Fare           1309 non-null float64
# Name           1309 non-null object
# Parch          1309 non-null int64
# PassengerId    1309 non-null int64
# Pclass         1309 non-null int64
# Sex            1309 non-null object
# SibSp          1309 non-null int64
# Survived       1309 non-null object
# Ticket         1309 non-null object
# Family_Size    1309 non-null int64
# dtypes: float64(2), int64(5), object(6)
# memory usage: 133.0+ KB

# %% [markdown]
# ## 2. ---------------------取出人稱謂---------------------

# %% [markdown]
# ### data['Name'].str.split(', ',expand=True)[0 or 1]

# %%
# 分割 name ,
# expand=True  ?????????????????????????????
# [1]          分割兩群之後，保留(前:0 或 後:1)
data['Title1']=data['Name'].str.split(', ',expand=True)[1]

# %%
data.head()
# Out:
#     Age Cabin Embarked     Fare  \
# 0  22.0   NaN        S   7.2500
# 1  38.0   C85        C  71.2833
# 2  26.0   NaN        S   7.9250
# 3  35.0  C123        S  53.1000
# 4  35.0   NaN        S   8.0500
#
#                                                 Name  Parch  PassengerId  \
# 0                            Braund, Mr. Owen Harris      0            1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...      0            2
# 2                             Heikkinen, Miss. Laina      0            3
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)      0            4
# 4                           Allen, Mr. William Henry      0            5
#
#    Pclass     Sex  SibSp Survived            Ticket  Family_Size  \
# 0       3    male      1        0         A/5 21171            1
# 1       1  female      1        1          PC 17599            1
# 2       3  female      0        1  STON/O2. 3101282            0
# 3       1  female      1        1            113803            1
# 4       3    male      0        0            373450            0
#
#                                        Title1
# 0                             Mr. Owen Harris
# 1  Mrs. John Bradley (Florence Briggs Thayer)
# 2                                 Miss. Laina
# 3          Mrs. Jacques Heath (Lily May Peel)
# 4                           Mr. William Henry

# %%
data['Name'].str.split(', ',expand=True).head(3)  #(看資料第幾筆)
# Out:
#            0                                           1
# 0     Braund                             Mr. Owen Harris
# 1    Cumings  Mrs. John Bradley (Florence Briggs Thayer)
# 2  Heikkinen                                 Miss. Laina

# %%
data['Title1'].head(3)
# Out:
# 0                               Mr. Owen Harris
# 1    Mrs. John Bradley (Florence Briggs Thayer)
# 2                                   Miss. Laina
# Name: Title1, dtype: object

# %%
# 分割 name .
data['Title1']=data['Title1'].str.split('. ',expand=True)[0]

# %%
data['Title1'].head(3)
# Out:
# 0      Mr
# 1     Mrs
# 2    Miss
# Name: Title1, dtype: object

# %%
#建立稱謂清單
data['Title1'].unique()
# Out:
# array(['Mr', 'Mrs', 'Miss', 'Master', 'Don', 'Rev', 'Dr', 'Mme', 'Ms',
#        'Major', 'Lady', 'Sir', 'Mlle', 'Col', 'Capt', 'th', 'Jonkheer',
#        'Dona'], dtype=object)

# %% [markdown]
# ## ------分析 :人稱謂、性別、生存率------

# %% [markdown]
# ### pd.crosstab(data['Title1'],data['Sex']).T.style.background_gradient(cmap='summer_r')

# %%
pd.crosstab(data['Title1'],data['Sex']).T.style.background_gradient(cmap='summer_r')
# Out:
#         <style  type="text/css" >
#
#
#             #T_153c00aa_43ae_11e8_8a42_0242ac110002row0_col0 {
#
#                 background-color:  #ffff66;
#
#             }
#
#             #T_153c00aa_43ae_11e8_8a42_0242ac110002row0_col1 {
#
#                 background-color:  #ffff66;
#
#             }
#
#             #T_153c00aa_43ae_11e8_8a42_0242ac110002row0_col2 {
#
#                 background-color:  #ffff66;
#
#             }
#
#             #T_153c00aa_43ae_11e8_8a42_0242ac110002row0_col3 {
#
#                 background-color:  #008066;
#
#             }
#
#             #T_153c00aa_43ae_11e8_8a42_0242ac110002row0_col4 {
#
#                 background-color:  #ffff66;
#
#             }
#
#             #T_153c00aa_43ae_11e8_8a42_0242ac110002row0_col5 {
#
#                 background-color:  #ffff66;
#
#             }
#
#             #T_153c00aa_43ae_11e8_8a42_0242ac110002row0_col6 {
#
#                 background-color:  #008066;
#
#             }
#
#             #T_153c00aa_43ae_11e8_8a42_0242ac110002row0_col7 {
#
#                 background-color:  #ffff66;
#
#             }
#
#             #T_153c00aa_43ae_11e8_8a42_0242ac110002row0_col8 {
#
#                 background-color:  #ffff66;
#
#             }
#
#             #T_153c00aa_43ae_11e8_8a42_0242ac110002row0_col9 {
#
#                 background-color:  #008066;
#
#             }
#
#             #T_153c00aa_43ae_11e8_8a42_0242ac110002row0_col10 {
#
#                 background-color:  #008066;
#
#             }
#
#             #T_153c00aa_43ae_11e8_8a42_0242ac110002row0_col11 {
#
#                 background-color:  #008066;
#
#             }
#
#             #T_153c00aa_43ae_11e8_8a42_0242ac110002row0_col12 {
#
#                 background-color:  #ffff66;
#
#             }
#
#             #T_153c00aa_43ae_11e8_8a42_0242ac110002row0_col13 {
#
#                 background-color:  #008066;
#
#             }
#
#             #T_153c00aa_43ae_11e8_8a42_0242ac110002row0_col14 {
#
#                 background-color:  #008066;
#
#             }
#
#             #T_153c00aa_43ae_11e8_8a42_0242ac110002row0_col15 {
#
#                 background-color:  #ffff66;
#
#             }
#
#             #T_153c00aa_43ae_11e8_8a42_0242ac110002row0_col16 {
#
#                 background-color:  #ffff66;
#
#             }
#
#             #T_153c00aa_43ae_11e8_8a42_0242ac110002row0_col17 {
#
#                 background-color:  #008066;
#
#             }
#
#             #T_153c00aa_43ae_11e8_8a42_0242ac110002row1_col0 {
#
#                 background-color:  #008066;
#
#             }
#
#             #T_153c00aa_43ae_11e8_8a42_0242ac110002row1_col1 {
#
#                 background-color:  #008066;
#
#             }
#
#             #T_153c00aa_43ae_11e8_8a42_0242ac110002row1_col2 {
#
#                 background-color:  #008066;
#
#             }
#
#             #T_153c00aa_43ae_11e8_8a42_0242ac110002row1_col3 {
#
#                 background-color:  #ffff66;
#
#             }
#
#             #T_153c00aa_43ae_11e8_8a42_0242ac110002row1_col4 {
#
#                 background-color:  #008066;
#
#             }
#
#             #T_153c00aa_43ae_11e8_8a42_0242ac110002row1_col5 {
#
#                 background-color:  #008066;
#
#             }
#
#             #T_153c00aa_43ae_11e8_8a42_0242ac110002row1_col6 {
#
#                 background-color:  #ffff66;
#
#             }
#
#             #T_153c00aa_43ae_11e8_8a42_0242ac110002row1_col7 {
#
#                 background-color:  #008066;
#
#             }
#
#             #T_153c00aa_43ae_11e8_8a42_0242ac110002row1_col8 {
#
#                 background-color:  #008066;
#
#             }
#
#             #T_153c00aa_43ae_11e8_8a42_0242ac110002row1_col9 {
#
#                 background-color:  #ffff66;
#
#             }
#
#             #T_153c00aa_43ae_11e8_8a42_0242ac110002row1_col10 {
#
#                 background-color:  #ffff66;
#
#             }
#
#             #T_153c00aa_43ae_11e8_8a42_0242ac110002row1_col11 {
#
#                 background-color:  #ffff66;
#
#             }
#
#             #T_153c00aa_43ae_11e8_8a42_0242ac110002row1_col12 {
#
#                 background-color:  #008066;
#
#             }
#
#             #T_153c00aa_43ae_11e8_8a42_0242ac110002row1_col13 {
#
#                 background-color:  #ffff66;
#
#             }
#
#             #T_153c00aa_43ae_11e8_8a42_0242ac110002row1_col14 {
#
#                 background-color:  #ffff66;
#
#             }
#
#             #T_153c00aa_43ae_11e8_8a42_0242ac110002row1_col15 {
#
#                 background-color:  #008066;
#
#             }
#
#             #T_153c00aa_43ae_11e8_8a42_0242ac110002row1_col16 {
#
#                 background-color:  #008066;
#
#             }
#
#             #T_153c00aa_43ae_11e8_8a42_0242ac110002row1_col17 {
#
#                 background-color:  #ffff66;
#
#             }
#
#         </style>
#
#         <table id="T_153c00aa_43ae_11e8_8a42_0242ac110002" None>
#
#
#         <thead>
#
#             <tr>
#
#
#                 <th class="index_name level0" >
#                   Title1
#
#
#
#                 <th class="col_heading level0 col0" colspan=1>
#                   Capt
#
#
#
#                 <th class="col_heading level0 col1" colspan=1>
#                   Col
#
#
#
#                 <th class="col_heading level0 col2" colspan=1>
#                   Don
#
#
#
#                 <th class="col_heading level0 col3" colspan=1>
#                   Dona
#
#
#
#                 <th class="col_heading level0 col4" colspan=1>
#                   Dr
#
#
#
#                 <th class="col_heading level0 col5" colspan=1>
#                   Jonkheer
#
#
#
#                 <th class="col_heading level0 col6" colspan=1>
#                   Lady
#
#
#
#                 <th class="col_heading level0 col7" colspan=1>
#                   Major
#
#
#
#                 <th class="col_heading level0 col8" colspan=1>
#                   Master
#
#
#
#                 <th class="col_heading level0 col9" colspan=1>
#                   Miss
#
#
#
#                 <th class="col_heading level0 col10" colspan=1>
#                   Mlle
#
#
#
#                 <th class="col_heading level0 col11" colspan=1>
#                   Mme
#
#
#
#                 <th class="col_heading level0 col12" colspan=1>
#                   Mr
#
#
#
#                 <th class="col_heading level0 col13" colspan=1>
#                   Mrs
#
#
#
#                 <th class="col_heading level0 col14" colspan=1>
#                   Ms

# %%
pd.crosstab(data['Title1'],data['Survived']).T.style.background_gradient(cmap='summer_r')
# Out:
#         <style  type="text/css" >
#
#
#             #T_154e9f4e_43ae_11e8_8a42_0242ac110002row0_col0 {
#
#                 background-color:  #008066;
#
#             }
#
#             #T_154e9f4e_43ae_11e8_8a42_0242ac110002row0_col1 {
#
#                 background-color:  #ffff66;
#
#             }
#
#             #T_154e9f4e_43ae_11e8_8a42_0242ac110002row0_col2 {
#
#                 background-color:  #008066;
#
#             }
#
#             #T_154e9f4e_43ae_11e8_8a42_0242ac110002row0_col3 {
#
#                 background-color:  #ffff66;
#
#             }
#
#             #T_154e9f4e_43ae_11e8_8a42_0242ac110002row0_col4 {
#
#                 background-color:  #008066;
#
#             }
#
#             #T_154e9f4e_43ae_11e8_8a42_0242ac110002row0_col5 {
#
#                 background-color:  #008066;
#
#             }
#
#             #T_154e9f4e_43ae_11e8_8a42_0242ac110002row0_col6 {
#
#                 background-color:  #ffff66;
#
#             }
#
#             #T_154e9f4e_43ae_11e8_8a42_0242ac110002row0_col7 {
#
#                 background-color:  #008066;
#
#             }
#
#             #T_154e9f4e_43ae_11e8_8a42_0242ac110002row0_col8 {
#
#                 background-color:  #ffff66;
#
#             }
#
#             #T_154e9f4e_43ae_11e8_8a42_0242ac110002row0_col9 {
#
#                 background-color:  #ffff66;
#
#             }
#
#             #T_154e9f4e_43ae_11e8_8a42_0242ac110002row0_col10 {
#
#                 background-color:  #ffff66;
#
#             }
#
#             #T_154e9f4e_43ae_11e8_8a42_0242ac110002row0_col11 {
#
#                 background-color:  #ffff66;
#
#             }
#
#             #T_154e9f4e_43ae_11e8_8a42_0242ac110002row0_col12 {
#
#                 background-color:  #008066;
#
#             }
#
#             #T_154e9f4e_43ae_11e8_8a42_0242ac110002row0_col13 {
#
#                 background-color:  #ffff66;
#
#             }
#
#             #T_154e9f4e_43ae_11e8_8a42_0242ac110002row0_col14 {
#
#                 background-color:  #ffff66;
#
#             }
#
#             #T_154e9f4e_43ae_11e8_8a42_0242ac110002row0_col15 {
#
#                 background-color:  #008066;
#
#             }
#
#             #T_154e9f4e_43ae_11e8_8a42_0242ac110002row0_col16 {
#
#                 background-color:  #ffff66;
#
#             }
#
#             #T_154e9f4e_43ae_11e8_8a42_0242ac110002row0_col17 {
#
#                 background-color:  #ffff66;
#
#             }
#
#             #T_154e9f4e_43ae_11e8_8a42_0242ac110002row1_col0 {
#
#                 background-color:  #ffff66;
#
#             }
#
#             #T_154e9f4e_43ae_11e8_8a42_0242ac110002row1_col1 {
#
#                 background-color:  #ffff66;
#
#             }
#
#             #T_154e9f4e_43ae_11e8_8a42_0242ac110002row1_col2 {
#
#                 background-color:  #ffff66;
#
#             }
#
#             #T_154e9f4e_43ae_11e8_8a42_0242ac110002row1_col3 {
#
#                 background-color:  #ffff66;
#
#             }
#
#             #T_154e9f4e_43ae_11e8_8a42_0242ac110002row1_col4 {
#
#                 background-color:  #55aa66;
#
#             }
#
#             #T_154e9f4e_43ae_11e8_8a42_0242ac110002row1_col5 {
#
#                 background-color:  #ffff66;
#
#             }
#
#             #T_154e9f4e_43ae_11e8_8a42_0242ac110002row1_col6 {
#
#                 background-color:  #008066;
#
#             }
#
#             #T_154e9f4e_43ae_11e8_8a42_0242ac110002row1_col7 {
#
#                 background-color:  #008066;
#
#             }
#
#             #T_154e9f4e_43ae_11e8_8a42_0242ac110002row1_col8 {
#
#                 background-color:  #008066;
#
#             }
#
#             #T_154e9f4e_43ae_11e8_8a42_0242ac110002row1_col9 {
#
#                 background-color:  #008066;
#
#             }
#
#             #T_154e9f4e_43ae_11e8_8a42_0242ac110002row1_col10 {
#
#                 background-color:  #008066;
#
#             }
#
#             #T_154e9f4e_43ae_11e8_8a42_0242ac110002row1_col11 {
#
#                 background-color:  #008066;
#
#             }
#
#             #T_154e9f4e_43ae_11e8_8a42_0242ac110002row1_col12 {
#
#                 background-color:  #ffff66;
#
#             }
#
#             #T_154e9f4e_43ae_11e8_8a42_0242ac110002row1_col13 {
#
#                 background-color:  #008066;
#
#             }
#
#             #T_154e9f4e_43ae_11e8_8a42_0242ac110002row1_col14 {
#
#                 background-color:  #008066;
#
#             }
#
#             #T_154e9f4e_43ae_11e8_8a42_0242ac110002row1_col15 {
#
#                 background-color:  #ffff66;
#
#             }
#
#             #T_154e9f4e_43ae_11e8_8a42_0242ac110002row1_col16 {
#
#                 background-color:  #008066;
#
#             }
#
#             #T_154e9f4e_43ae_11e8_8a42_0242ac110002row1_col17 {
#
#                 background-color:  #008066;
#
#             }
#
#             #T_154e9f4e_43ae_11e8_8a42_0242ac110002row2_col0 {
#
#                 background-color:  #ffff66;
#
#             }
#
#             #T_154e9f4e_43ae_11e8_8a42_0242ac110002row2_col1 {
#
#                 background-color:  #008066;
#
#             }
#
#             #T_154e9f4e_43ae_11e8_8a42_0242ac110002row2_col2 {
#
#                 background-color:  #ffff66;
#
#             }
#
#             #T_154e9f4e_43ae_11e8_8a42_0242ac110002row2_col3 {
#
#                 background-color:  #008066;
#
#             }
#
#             #T_154e9f4e_43ae_11e8_8a42_0242ac110002row2_col4 {
#
#                 background-color:  #ffff66;
#
#             }
#
#             #T_154e9f4e_43ae_11e8_8a42_0242ac110002row2_col5 {
#
#                 background-color:  #ffff66;
#
#             }
#
#             #T_154e9f4e_43ae_11e8_8a42_0242ac110002row2_col6 {
#
#                 background-color:  #ffff66;
#
#             }
#
#             #T_154e9f4e_43ae_11e8_8a42_0242ac110002row2_col7 {
#
#                 background-color:  #ffff66;
#
#             }
#
#             #T_154e9f4e_43ae_11e8_8a42_0242ac110002row2_col8 {
#
#                 background-color:  #55aa66;
#
#             }
#
#             #T_154e9f4e_43ae_11e8_8a42_0242ac110002row2_col9 {
#
#                 background-color:  #aed666;
#
#             }
#
#             #T_154e9f4e_43ae_11e8_8a42_0242ac110002row2_col10 {
#
#                 background-color:  #ffff66;
#
#             }
#
#             #T_154e9f4e_43ae_11e8_8a42_0242ac110002row2_col11 {
#
#                 background-color:  #ffff66;
#
#             }
#
#             #T_154e9f4e_43ae_11e8_8a42_0242ac110002row2_col12 {
#
#                 background-color:  #8dc666;
#
#             }
#
#             #T_154e9f4e_43ae_11e8_8a42_0242ac110002row2_col13 {
#
#                 background-color:  #5eae66;
#
#             }
#
#             #T_154e9f4e_43ae_11e8_8a42_0242ac110002row2_col14 {
#
#                 background-color:  #008066;

# %%
# groupby稱謂，計算平均年齡
data.groupby(['Title1'])['Age'].mean()
# Out:
# Title1
# Capt        70.000000
# Col         54.000000
# Don         40.000000
# Dona        39.000000
# Dr          41.860142
# Jonkheer    38.000000
# Lady        48.000000
# Major       48.500000
# Master       8.682444
# Miss        23.333257
# Mlle        24.000000
# Mme         24.000000
# Mr          31.700899
# Mrs         36.019242
# Ms          28.940569
# Rev         41.250000
# Sir         49.000000
# th          33.000000
# Name: Age, dtype: float64

# %%
data.groupby(['Title1','Pclass'])['Age'].mean()
# Out:
# Title1    Pclass
# Capt      1         70.000000
# Col       1         54.000000
# Don       1         40.000000
# Dona      1         39.000000
# Dr        1         42.980190
#           2         38.500000
# Jonkheer  1         38.000000
# Lady      1         48.000000
# Major     1         48.500000
# Master    1          6.984000
#           2          2.757273
#           3         10.319536
# Miss      1         30.331352
#           2         21.083646
#           3         21.283890
# Mlle      1         24.000000
# Mme       1         24.000000
# Mr        1         39.486105
#           2         32.133032
#           3         28.793158
# Mrs       1         41.478070
#           2         33.452384
#           3         31.724588
# Ms        2         28.000000
#           3         29.881138
# Rev       2         41.250000
# Sir       1         49.000000
# th        1         33.000000
# Name: Age, dtype: float64

# %% [markdown]
# ##  覆寫少數稱謂成 Miss Mrs Mr。
# #### 某些稱謂的乘客佔少數，多了某些稱謂欄，對於機器學習模型，不是好事。故將少數稱謂覆寫。

# %% [markdown]
# ### data['Title2']=data['Title1'].replace([name...] , [name1...])

# %%
data['Title2']=data['Title1'].replace(['Mlle','Mme','Ms','Dr','Major','Lady','th','Don','Rev','Sir','Col','Capt','Jonkheer','Dona'],
                                     ['Miss','Mrs','Miss','Mr','Mr','Mrs','Mrs','Mr','Mr','Mr','Mr','Mr','Mr','Mrs'])

# %%
data['Title2'].unique()
# Out:
# array(['Mr', 'Mrs', 'Miss', 'Master'], dtype=object)

# %%
pd.crosstab(data['Title2'],data['Sex']).T.style.background_gradient(cmap='summer_r')
# Out:
#         <style  type="text/css" >
#
#
#             #T_162690f2_43ae_11e8_8a42_0242ac110002row0_col0 {
#
#                 background-color:  #ffff66;
#
#             }
#
#             #T_162690f2_43ae_11e8_8a42_0242ac110002row0_col1 {
#
#                 background-color:  #008066;
#
#             }
#
#             #T_162690f2_43ae_11e8_8a42_0242ac110002row0_col2 {
#
#                 background-color:  #ffff66;
#
#             }
#
#             #T_162690f2_43ae_11e8_8a42_0242ac110002row0_col3 {
#
#                 background-color:  #008066;
#
#             }
#
#             #T_162690f2_43ae_11e8_8a42_0242ac110002row1_col0 {
#
#                 background-color:  #008066;
#
#             }
#
#             #T_162690f2_43ae_11e8_8a42_0242ac110002row1_col1 {
#
#                 background-color:  #ffff66;
#
#             }
#
#             #T_162690f2_43ae_11e8_8a42_0242ac110002row1_col2 {
#
#                 background-color:  #008066;
#
#             }
#
#             #T_162690f2_43ae_11e8_8a42_0242ac110002row1_col3 {
#
#                 background-color:  #ffff66;
#
#             }
#
#         </style>
#
#         <table id="T_162690f2_43ae_11e8_8a42_0242ac110002" None>
#
#
#         <thead>
#
#             <tr>
#
#
#                 <th class="index_name level0" >
#                   Title2
#
#
#
#                 <th class="col_heading level0 col0" colspan=1>
#                   Master
#
#
#
#                 <th class="col_heading level0 col1" colspan=1>
#                   Miss
#
#
#
#                 <th class="col_heading level0 col2" colspan=1>
#                   Mr
#
#
#
#                 <th class="col_heading level0 col3" colspan=1>
#                   Mrs
#
#
#             </tr>
#
#             <tr>
#
#
#                 <th class="index_name level0" >
#                   Sex
#
#
#
#                 <th class="blank" >
#
#
#
#
#                 <th class="blank" >
#
#
#
#
#                 <th class="blank" >
#
#
#
#
#                 <th class="blank" >
#
#
#
#             </tr>
#
#         </thead>
#         <tbody>
#
#             <tr>
#
#
#                 <th id="T_162690f2_43ae_11e8_8a42_0242ac110002"
#                  class="row_heading level0 row0" rowspan=1>
#                     female
#
#
#
#                 <td id="T_162690f2_43ae_11e8_8a42_0242ac110002row0_col0"
#                  class="data row0 col0" >
#                     0
#
#
#
#                 <td id="T_162690f2_43ae_11e8_8a42_0242ac110002row0_col1"
#                  class="data row0 col1" >
#                     264
#
#
#
#                 <td id="T_162690f2_43ae_11e8_8a42_0242ac110002row0_col2"
#                  class="data row0 col2" >
#                     1
#
#
#
#                 <td id="T_162690f2_43ae_11e8_8a42_0242ac110002row0_col3"
#                  class="data row0 col3" >
#                     201
#
#
#             </tr>
#
#             <tr>
#
#
#                 <th id="T_162690f2_43ae_11e8_8a42_0242ac110002"
#                  class="row_heading level0 row1" rowspan=1>
#                     male
#
#
#
#                 <td id="T_162690f2_43ae_11e8_8a42_0242ac110002row1_col0"
#                  class="data row1 col0" >
#                     61
#
#
#
#                 <td id="T_162690f2_43ae_11e8_8a42_0242ac110002row1_col1"
#                  class="data row1 col1" >
#                     0
#
#
#
#                 <td id="T_162690f2_43ae_11e8_8a42_0242ac110002row1_col2"
#                  class="data row1 col2" >
#                     782
#
#
#
#                 <td id="T_162690f2_43ae_11e8_8a42_0242ac110002row1_col3"
#                  class="data row1 col3" >
#                     0
#
#
#             </tr>
#
#         </tbody>
#         </table>

# %%
pd.crosstab(data['Title2'],data['Survived']).T.style.background_gradient(cmap='summer_r')
# Out:
#         <style  type="text/css" >
#
#
#             #T_1641c67e_43ae_11e8_8a42_0242ac110002row0_col0 {
#
#                 background-color:  #ffff66;
#
#             }
#
#             #T_1641c67e_43ae_11e8_8a42_0242ac110002row0_col1 {
#
#                 background-color:  #ffff66;
#
#             }
#
#             #T_1641c67e_43ae_11e8_8a42_0242ac110002row0_col2 {
#
#                 background-color:  #008066;
#
#             }
#
#             #T_1641c67e_43ae_11e8_8a42_0242ac110002row0_col3 {
#
#                 background-color:  #ffff66;
#
#             }
#
#             #T_1641c67e_43ae_11e8_8a42_0242ac110002row1_col0 {
#
#                 background-color:  #008066;
#
#             }
#
#             #T_1641c67e_43ae_11e8_8a42_0242ac110002row1_col1 {
#
#                 background-color:  #008066;
#
#             }
#
#             #T_1641c67e_43ae_11e8_8a42_0242ac110002row1_col2 {
#
#                 background-color:  #ffff66;
#
#             }
#
#             #T_1641c67e_43ae_11e8_8a42_0242ac110002row1_col3 {
#
#                 background-color:  #008066;
#
#             }
#
#             #T_1641c67e_43ae_11e8_8a42_0242ac110002row2_col0 {
#
#                 background-color:  #55aa66;
#
#             }
#
#             #T_1641c67e_43ae_11e8_8a42_0242ac110002row2_col1 {
#
#                 background-color:  #aed666;
#
#             }
#
#             #T_1641c67e_43ae_11e8_8a42_0242ac110002row2_col2 {
#
#                 background-color:  #90c866;
#
#             }
#
#             #T_1641c67e_43ae_11e8_8a42_0242ac110002row2_col3 {
#
#                 background-color:  #61b066;
#
#             }
#
#         </style>
#
#         <table id="T_1641c67e_43ae_11e8_8a42_0242ac110002" None>
#
#
#         <thead>
#
#             <tr>
#
#
#                 <th class="index_name level0" >
#                   Title2
#
#
#
#                 <th class="col_heading level0 col0" colspan=1>
#                   Master
#
#
#
#                 <th class="col_heading level0 col1" colspan=1>
#                   Miss
#
#
#
#                 <th class="col_heading level0 col2" colspan=1>
#                   Mr
#
#
#
#                 <th class="col_heading level0 col3" colspan=1>
#                   Mrs
#
#
#             </tr>
#
#             <tr>
#
#
#                 <th class="index_name level0" >
#                   Survived
#
#
#
#                 <th class="blank" >
#
#
#
#
#                 <th class="blank" >
#
#
#
#
#                 <th class="blank" >
#
#
#
#
#                 <th class="blank" >
#
#
#
#             </tr>
#
#         </thead>
#         <tbody>
#
#             <tr>
#
#
#                 <th id="T_1641c67e_43ae_11e8_8a42_0242ac110002"
#                  class="row_heading level0 row0" rowspan=1>
#                     0.0
#
#
#
#                 <td id="T_1641c67e_43ae_11e8_8a42_0242ac110002row0_col0"
#                  class="data row0 col0" >
#                     17
#
#
#
#                 <td id="T_1641c67e_43ae_11e8_8a42_0242ac110002row0_col1"
#                  class="data row0 col1" >
#                     55
#
#
#
#                 <td id="T_1641c67e_43ae_11e8_8a42_0242ac110002row0_col2"
#                  class="data row0 col2" >
#                     451
#
#
#
#                 <td id="T_1641c67e_43ae_11e8_8a42_0242ac110002row0_col3"
#                  class="data row0 col3" >
#                     26
#
#
#             </tr>
#
#             <tr>
#
#
#                 <th id="T_1641c67e_43ae_11e8_8a42_0242ac110002"
#                  class="row_heading level0 row1" rowspan=1>
#                     1.0
#
#
#
#                 <td id="T_1641c67e_43ae_11e8_8a42_0242ac110002row1_col0"
#                  class="data row1 col0" >
#                     23
#
#
#
#                 <td id="T_1641c67e_43ae_11e8_8a42_0242ac110002row1_col1"
#                  class="data row1 col1" >
#                     130
#
#
#
#                 <td id="T_1641c67e_43ae_11e8_8a42_0242ac110002row1_col2"
#                  class="data row1 col2" >
#                     87
#
#
#
#                 <td id="T_1641c67e_43ae_11e8_8a42_0242ac110002row1_col3"
#                  class="data row1 col3" >
#                     102
#
#
#             </tr>
#
#             <tr>
#
#
#                 <th id="T_1641c67e_43ae_11e8_8a42_0242ac110002"
#                  class="row_heading level0 row2" rowspan=1>
#                     0
#
#
#
#                 <td id="T_1641c67e_43ae_11e8_8a42_0242ac110002row2_col0"
#                  class="data row2 col0" >
#                     21
#
#
#
#                 <td id="T_1641c67e_43ae_11e8_8a42_0242ac110002row2_col1"
#                  class="data row2 col1" >
#                     79
#
#
#
#                 <td id="T_1641c67e_43ae_11e8_8a42_0242ac110002row2_col2"
#                  class="data row2 col2" >
#                     245
#
#
#
#                 <td id="T_1641c67e_43ae_11e8_8a42_0242ac110002row2_col3"
#                  class="data row2 col3" >
#                     73
#
#
#             </tr>
#
#         </tbody>
#         </table>

# %%
data.groupby('Title2')['Age'].mean()
# Out:
# Title2
# Master     8.682444
# Miss      23.380788
# Mr        32.148737
# Mrs       36.018859
# Name: Age, dtype: float64

# %%
data.groupby(['Title2','Pclass'])['Age'].mean()
# Out:
# Title2  Pclass
# Master  1          6.984000
#         2          2.757273
#         3         10.319536
# Miss    1         30.127115
#         2         21.219260
#         3         21.340825
# Mr      1         40.263839
#         2         32.668467
#         3         28.793158
# Mrs     1         41.207548
#         2         33.452384
#         3         31.724588
# Name: Age, dtype: float64

# %%
list(data.groupby(['Title2','Pclass'])['Age'].mean().iteritems())[:3]
# Out:
# [(('Master', 1), 6.984),
#  (('Master', 2), 2.7572727272727273),
#  (('Master', 3), 10.319535585298491)]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 15 columns):
# Age            1309 non-null float64
# Cabin          295 non-null object
# Embarked       1309 non-null object
# Fare           1309 non-null float64
# Name           1309 non-null object
# Parch          1309 non-null int64
# PassengerId    1309 non-null int64
# Pclass         1309 non-null int64
# Sex            1309 non-null object
# SibSp          1309 non-null int64
# Survived       1309 non-null object
# Ticket         1309 non-null object
# Family_Size    1309 non-null int64
# Title1         1309 non-null object
# Title2         1309 non-null object
# dtypes: float64(2), int64(5), object(8)
# memory usage: 153.5+ KB

# %% [markdown]
# ## 3. ----------取出票號 前面英文(房間)------------

# %% [markdown]
# ### .apply(lambda x : x.replace(".","").replace("/","").strip().split(' ')[0] if not x.isdigit() else 'X')

# %%
data['Ticket_info'] = data['Ticket'].apply(lambda x : x.replace(".","").replace("/","").strip().split(' ')[0] if not x.isdigit() else 'X')

# %%
data['Ticket_info'].unique()
# Out:
# array(['A5', 'PC', 'STONO2', 'X', 'PP', 'CA', 'SCParis', 'SCA4', 'A4',
#        'SP', 'SOC', 'WC', 'SOTONOQ', 'WEP', 'STONO', 'C', 'SCPARIS', 'SOP',
#        'Fa', 'LINE', 'FCC', 'SWPP', 'SCOW', 'PPP', 'SC', 'SCAH', 'AS',
#        'SOPP', 'FC', 'SOTONO2', 'CASOTON', 'SCA3', 'STONOQ', 'AQ4', 'A',
#        'LP', 'AQ3'], dtype=object)

# %%
# Ticket_info(房間)為間斷資料
sns.countplot(data['Ticket_info'], hue=data['Survived'])

# %% [markdown]
# ## 3.------------------- 客艙、生存率 -------------------

# %%
data['Cabin'].head(10)
# Out:
# 0     NaN
# 1     C85
# 2     NaN
# 3    C123
# 4     NaN
# 5     NaN
# 6     E46
# 7     NaN
# 8     NaN
# 9     NaN
# Name: Cabin, dtype: object

# %%
# 選出客艙第一個字母 ，缺值則改為'NoCabin'
data["Cabin"] = data['Cabin'].apply(lambda x : str(x)[0] if not pd.isnull(x) else 'NoCabin')

# %%
# 建立客艙清單
data["Cabin"].unique()
# Out:
# array(['NoCabin', 'C', 'E', 'G', 'D', 'A', 'B', 'F', 'T'], dtype=object)

# %%
# Cabin(客艙)為間斷資料
sns.countplot(data['Cabin'], hue=data['Survived'])

# %% [markdown]
# #  【將類別資料轉為整數】

# %%
data.head(5)
# Out:
#     Age    Cabin Embarked     Fare  \
# 0  22.0  NoCabin        S   7.2500
# 1  38.0        C        C  71.2833
# 2  26.0  NoCabin        S   7.9250
# 3  35.0        C        S  53.1000
# 4  35.0  NoCabin        S   8.0500
#
#                                                 Name  Parch  PassengerId  \
# 0                            Braund, Mr. Owen Harris      0            1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...      0            2
# 2                             Heikkinen, Miss. Laina      0            3
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)      0            4
# 4                           Allen, Mr. William Henry      0            5
#
#    Pclass     Sex  SibSp Survived            Ticket  Family_Size Title1  \
# 0       3    male      1        0         A/5 21171            1     Mr
# 1       1  female      1        1          PC 17599            1    Mrs
# 2       3  female      0        1  STON/O2. 3101282            0   Miss
# 3       1  female      1        1            113803            1    Mrs
# 4       3    male      0        0            373450            0     Mr
#
#   Title2 Ticket_info
# 0     Mr          A5
# 1    Mrs          PC
# 2   Miss      STONO2
# 3    Mrs           X
# 4     Mr           X

# %%
data['Cabin'] = data['Cabin'].astype('category').cat.codes
data['Embarked'] = data['Embarked'].astype('category').cat.codes
data['Sex'] = data['Sex'].astype('category').cat.codes
data['Pclass'] = data['Pclass'].astype('category').cat.codes
data['Title1'] = data['Title1'].astype('category').cat.codes
data['Title2'] = data['Title2'].astype('category').cat.codes
data['Ticket_info'] = data['Ticket_info'].astype('category').cat.codes

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 16 columns):
# Age            1309 non-null float64
# Cabin          1309 non-null int8
# Embarked       1309 non-null int8
# Fare           1309 non-null float64
# Name           1309 non-null object
# Parch          1309 non-null int64
# PassengerId    1309 non-null int64
# Pclass         1309 non-null int8
# Sex            1309 non-null int8
# SibSp          1309 non-null int64
# Survived       1309 non-null object
# Ticket         1309 non-null object
# Family_Size    1309 non-null int64
# Title1         1309 non-null int8
# Title2         1309 non-null int8
# Ticket_info    1309 non-null int8
# dtypes: float64(2), int64(4), int8(7), object(3)
# memory usage: 101.1+ KB

# %%
selected_features = ['Age','Cabin','Embarked','Fare','Parch','Pclass','Sex','Parch','SibSp','Family_Size','Title2','Ticket_info']

# %%
# ------------------------------------------ X_train ------------------------------------------
X = data[selected_features]

# %%
X.head(3)
# Out:
#     Age  Cabin  Embarked     Fare  Parch  Pclass  Sex  Parch  SibSp  \
# 0  22.0      7         2   7.2500      0       2    1      0      1
# 1  38.0      2         0  71.2833      0       0    0      0      1
# 2  26.0      7         2   7.9250      0       2    0      0      0
#
#    Family_Size  Title2  Ticket_info
# 0            1       2            2
# 1            1       3           14
# 2            0       1           31

# %%
type(X)
# Out:
# pandas.core.frame.DataFrame

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 12 columns):
# Age            1309 non-null float64
# Cabin          1309 non-null int8
# Embarked       1309 non-null int8
# Fare           1309 non-null float64
# Parch          1309 non-null int64
# Pclass         1309 non-null int8
# Sex            1309 non-null int8
# Parch          1309 non-null int64
# SibSp          1309 non-null int64
# Family_Size    1309 non-null int64
# Title2         1309 non-null int8
# Ticket_info    1309 non-null int8
# dtypes: float64(2), int64(4), int8(6)
# memory usage: 69.1 KB

# %%
X.astype(int)
# Out:
#       Age  Cabin  Embarked  Fare  Parch  Pclass  Sex  Parch  SibSp  \
# 0      22      7         2     7      0       2    1      0      1
# 1      38      2         0    71      0       0    0      0      1
# 2      26      7         2     7      0       2    0      0      0
# 3      35      2         2    53      0       0    0      0      1
# 4      35      7         2     8      0       2    1      0      0
# 5      29      7         1     8      0       2    1      0      0
# 6      54      4         2    51      0       0    1      0      0
# 7       2      7         2    21      1       2    1      1      3
# 8      27      7         2    11      2       2    0      2      0
# 9      14      7         0    30      0       1    0      0      1
# 10      4      6         2    16      1       2    0      1      1
# 11     58      2         2    26      0       0    0      0      0
# 12     20      7         2     8      0       2    1      0      0
# 13     39      7         2    31      5       2    1      5      1
# 14     14      7         2     7      0       2    0      0      0
# 15     55      7         2    16      0       1    0      0      0
# 16      2      7         1    29      1       2    1      1      4
# 17     29      7         2    13      0       1    1      0      0
# 18     31      7         2    18      0       2    0      0      1
# 19     29      7         0     7      0       2    0      0      0
# 20     35      7         2    26      0       1    1      0      0
# 21     34      3         2    13      0       1    1      0      0
# 22     15      7         1     8      0       2    0      0      0
# 23     28      0         2    35      0       0    1      0      0
# 24      8      7         2    21      1       2    0      1      3
# 25     38      7         2    31      5       2    0      5      1
# 26     29      7         0     7      0       2    1      0      0
# 27     19      2         2   263      2       0    1      2      3
# 28     29      7         1     7      0       2    0      0      0
# 29     29      7         2     7      0       2    1      0      0
# ...   ...    ...       ...   ...    ...     ...  ...    ...    ...
# 1279   21      7         1     7      0       2    1      0      0
# 1280    6      7         2    21      1       2    1      1      3
# 1281   23      1         2    93      0       0    1      0      0
# 1282   51      3         2    39      1       0    0      1      0
# 1283   13      7         2    20      2       2    1      2      0
# 1284   47      7         2    10      0       1    1      0      0
# 1285   29      7         2    22      1       2    1      1      3
# 1286   18      2         2    60      0       0    0      0      1
# 1287   24      7         1     7      0       2    1      0      0
# 1288   48      1         0    79      1       0    0      1      1
# 1289   22      7         2     7      0       2    1      0      0
# 1290   31      7         1     7      0       2    1      0      0
# 1291   30      2         2   164      0       0    0      0      0
# 1292   38      7         2    21      0       1    1      0      1
# 1293   22      7         0    59      1       0    0      1      0
# 1294   17      7         2    47      0       0    1      0      0
# 1295   43      3         0    27      0       0    1      0      1
# 1296   20      3         0    13      0       1    1      0      0
# 1297   23      7         2    10      0       1    1      0      1
# 1298   50      2         0   211      1       0    1      1      1
# 1299   29      7         1     7      0       2    0      0      0
# 1300    3      7         2    13      1       2    0      1      1
# 1301   29      7         1     7      0       2    0      0      0
# 1302   37      2         1    90      0       0    0      0      1
# 1303   28      7         2     7      0       2    0      0      0
# 1304   29      7         2     8      0       2    1      0      0
# 1305   39      2         0   108      0       0    0      0      0
# 1306   38      7         2     7      0       2    1      0      0
# 1307   29      7         2     8      0       2    1      0      0
# 1308   29      7         0    22      1       2    1      1      1
#
#       Family_Size  Title2  Ticket_info
# 0               1       2            2
# 1               1       3           14
# 2               0       1           31
# 3               1       3           36
# 4               0       2           36
# 5               0       2           36
# 6               0       2           36
# 7               4       0           36
# 8               2       3           36
# 9               1       3           36
# 10              2       1           15
# 11              0       1           36
# 12              0       2            2
# 13              6       2           36
# 14              0       1           36
# 15              0       3           36
# 16              5       0           36
# 17              0       2           36
# 18              1       3           36
# 19              0       3           36
# 20              0       2           36
# 21              0       2           36
# 22              0       1           36
# 23              0       2           36
# 24              4       1           36
# 25              6       3           36
# 26              0       2           36
# 27              5       2           36
# 28              0       1           36
# 29              0       2           36
# ...           ...     ...          ...
# 1279            0       2           36
# 1280            4       0           36
# 1281            0       2           36
# 1282            1       3           14
# 1283            2       0            7
# 1284            0       2            7
# 1285            4       2           36
# 1286            1       3           36
# 1287            0       2           36
# 1288            2       3           36
# 1289            0       2           36
# 1290            0       2           36
# 1291            0       1           36
# 1292            1       2           36
# 1293            1       1           36
# 1294            0       2           36
# 1295            1       2           36
# 1296            0       2           22
# 1297            1       2           36
# 1298            2       2           36
# 1299            0       1           36
# 1300            2       1           28
# 1301            0       1           36
# 1302            1       3           36
# 1303            0       1           36
# 1304            0       2            2
# 1305            0       3           14
# 1306            0       2           28
# 1307            0       2           36
# 1308            2       0           36
#
# [1309 rows x 12 columns]

# %%
# ------------------------------------------ y_train ------------------------------------------
Y = data['Survived']

# %%
Y.head(3)
# Out:
# 0    0
# 1    1
# 2    1
# Name: Survived, dtype: object

# %%
type(Y)
# Out:
# pandas.core.series.Series

# %%
Y.astype(int)
# Out:
# 0       0
# 1       1
# 2       1
# 3       1
# 4       0
# 5       0
# 6       0
# 7       0
# 8       1
# 9       1
# 10      1
# 11      1
# 12      0
# 13      0
# 14      0
# 15      1
# 16      0
# 17      1
# 18      0
# 19      1
# 20      0
# 21      1
# 22      1
# 23      1
# 24      0
# 25      1
# 26      0
# 27      0
# 28      1
# 29      0
#        ..
# 1279    0
# 1280    0
# 1281    0
# 1282    0
# 1283    0
# 1284    0
# 1285    0
# 1286    0
# 1287    0
# 1288    0
# 1289    0
# 1290    0
# 1291    0
# 1292    0
# 1293    0
# 1294    0
# 1295    0
# 1296    0
# 1297    0
# 1298    0
# 1299    0
# 1300    0
# 1301    0
# 1302    0
# 1303    0
# 1304    0
# 1305    0
# 1306    0
# 1307    0
# 1308    0
# Name: Survived, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=9487)

# %%
# 建立 Random Forest 模組
rfc = RandomForestClassifier()

# %%
#cross_val_score(rfc, X_train, y_train, cv=10).mean()

# %%
type(y_train)
# Out:
# pandas.core.series.Series

# %%
rfc.fit(x_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-67-50ce4f6b0dc9> in <module>()
# ----> 1 rfc.fit(x_train, y_train)
#
# /opt/conda/lib/python3.6/site-packages/sklearn/ensemble/forest.py in fit(self, X, y, sample_weight)
#     269         self.n_outputs_ = y.shape[1]
#     270
# --> 271         y, expanded_class_weight = self._validate_y_class_weight(y)
#     272
#     273         if getattr(y, "dtype", None) != DOUBLE or not y.flags.contiguous:
#
# /opt/conda/lib/python3.6/site-packages/sklearn/ensemble/forest.py in _validate_y_class_weight(self, y)
#     455
#     456     def _validate_y_class_weight(self, y):
# --> 457         check_classification_targets(y)
#     458
#     459         y = np.copy(y)
#
# /opt/conda/lib/python3.6/site-packages/sklearn/utils/multiclass.py in check_classification_targets(y)
#     170     if y_type not in ['binary', 'multiclass', 'multiclass-multioutput',
#     171             'multilabel-indicator', 'multilabel-sequences']:
# --> 172         raise ValueError("Unknown label type: %r" % y_type)
#     173
#     174
#
# ValueError: Unknown label type: 'unknown'

# %%
survived_predict = rfc.predict(X_test)

# %%
submission=pd.DataFrame({'PassengerId':test['PassengerId'], 'Survived':survived_predict})

# %%
submission.to_csv('submission.csv', index=False)

# %% [markdown]
# # 【使用隨機森林來推測年齡】

# %%
dataAgeNull = data[data["Age"].isnull()]
dataAgeNotNull = data[data["Age"].notnull()]
remove_outlier = dataAgeNotNull[(np.abs(dataAgeNotNull["Fare"]-dataAgeNotNull["Fare"].mean())>(4*dataAgeNotNull["Fare"].std()))|
                      (np.abs(dataAgeNotNull["Family_Size"]-dataAgeNotNull["Family_Size"].mean())>(4*dataAgeNotNull["Family_Size"].std()))                     
                     ]
rfModel_age = RandomForestRegressor(n_estimators=2000,random_state=42)
ageColumns = ['Embarked', 'Fare', 'Pclass', 'Sex', 'Family_Size', 'Title1', 'Title2','Cabin','Ticket_info']
rfModel_age.fit(remove_outlier[ageColumns], remove_outlier["Age"])

ageNullValues = rfModel_age.predict(X= dataAgeNull[ageColumns])
dataAgeNull.loc[:,"Age"] = ageNullValues
data = dataAgeNull.append(dataAgeNotNull)
data.reset_index(inplace=True, drop=True)

# %%
dataTrain = data[pd.notnull(data['Survived'])].sort_values(by=["PassengerId"])
dataTest = data[~pd.notnull(data['Survived'])].sort_values(by=["PassengerId"])

# %%
dataTrain.columns

# %%
dataTrain = dataTrain[['Survived', 'Age', 'Embarked', 'Fare',  'Pclass', 'Sex', 'Family_Size', 'Title2','Ticket_info','Cabin']]
dataTest = dataTest[['Age', 'Embarked', 'Fare', 'Pclass', 'Sex', 'Family_Size', 'Title2','Ticket_info','Cabin']]

# %%
dataTrain

# %% [markdown]
# # 【Random Forest　預測存活率】

# %%
from sklearn.ensemble import RandomForestClassifier
 
rf = RandomForestClassifier(criterion='gini', 
                             n_estimators=1000,
                             min_samples_split=12,
                             min_samples_leaf=1,
                             oob_score=True,
                             random_state=1,
                             n_jobs=-1) 

rf.fit(dataTrain.iloc[:, 1:], dataTrain.iloc[:, 0])
print("%.4f" % rf.oob_score_)

# %%
pd.concat((pd.DataFrame(dataTrain.iloc[:, 1:].columns, columns = ['variable']), 
           pd.DataFrame(rf.feature_importances_, columns = ['importance'])), 
          axis = 1).sort_values(by='importance', ascending = False)[:20]

# %% [markdown]
# # 【將欲提交至kaggle的檔案寫出】

# %%
submission=pd.DataFrame({'PassengerId':test['PassengerId'], 'Survived':survived_predict})

# %%
rf_res =  rf.predict(dataTest)
submit['Survived'] = rf_res
submit['Survived'] = submit['Survived'].astype(int)
submit.to_csv('submit.csv', index= False)

# %%
submit
